# %% [markdown]
# ## SUPERMARKET DATA ANALYSIS
#  Firdavs Yusupov
#
# E-mail: firdavsyusupov.pc.uz@gmail.com

# %% [markdown]
# ## Importing the required libraries

# %%
import matplotlib.patches as mpatches
from datetime import datetime, time 
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing the dataset

# %%
# CSV to -> DF
csv_file = pd.read_csv('sotuvlar.csv')
df = pd.DataFrame(csv_file)
#df.info() # Check DataType 
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
# SORT AND FILTER

# %%
# SORT AND FILTER
a_branch = df.query('Branch=="A"')
b_branch = df.query('Branch=="B"')
c_branch = df.query('Branch=="C"')
a_counts = a_branch['Gender'].value_counts()
b_counts = b_branch['Gender'].value_counts()
c_counts = c_branch['Gender'].value_counts()
df['Date']= pd.to_datetime(df.Date) # If the code doesn't work: + format ='%m/%d/%y'
#df['Time']= pd.to_datetime(df.Time, format='%H:%M')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df[['Branch','City', 'Gender']]
#plt.subplot(132)
compare = df['Gender'].value_counts()
compare.plot(kind='bar')
#plt.grid(axis='y')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Biz Male(Erkak) va Female(Ayol) kanchaligini kuzatshimiz mumkun

# %%
df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %% [markdown]
# Korishingiz mumkun:
#  Female(Ayol) bizda 501 odam |
#  Male(Erkak) bizda 499 odam

# %%
sns.catplot(data = df, x='Branch', kind='count', hue='Gender')
plt.show()

# %%
sns.catplot(data = df, x='Gender', kind='count', hue='Branch', order=['Male','Female'])
plt.grid(axis='y')
plt.show()

# %%
sns.catplot(data = df, x='Branch', kind='count', hue='City')
plt.grid(axis='y')
plt.show()

# %%
sns.catplot(data=df, x='Product line', y='Unit price', kind='bar', ci=None); # order=category_order -  
#plt.subplot(figsize=(10,20))
#plt.barh( df['Product line'], df['Unit price'])
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %%
#plt.subplot(131)
sns.catplot(data = df, x='Branch', kind='count', hue='Quantity')
plt.grid(axis='y')

#plt.subplot(132)
sns.catplot(data = df, x='Product line', kind='count', hue='Quantity')
plt.grid(axis='y')
plt.xticks(rotation=90)

plt.show()

# %%
sns.catplot(data = df, x='Branch', kind='count', hue='gross income')

plt.show()
